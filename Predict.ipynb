# %% [markdown]
# # Load model
# Place the model inside `Kaggle` folder inside your google drive and name it `model.h5`

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir model
# !cp "/content/drive/My Drive/Kaggle/model.h5" model/model.h5
# !ls model
# Out:
# model.h5

# %% [markdown]
# Dependencies

# %%
import tensorflow as tf

# %% [markdown]
# Load model

# %%
labels = {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %%
model = tf.keras.models.load_model("model/model.h5")

# %%
import matplotlib.pyplot as plt
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  path = '/content/' + fn
  img = image.load_img(path, target_size=(300, 300))
  img = image.img_to_array(img, dtype=np.uint8)
  img=np.array(img)/255.0

  plt.title("Loaded Image")
  plt.axis('off')
  plt.imshow(img.squeeze())

  p=model.predict(img[np.newaxis, ...])

  print("Maximum Probability: ",np.max(p[0], axis=-1))
  predicted_class = labels[np.argmax(p[0], axis=-1)]
  print("Classified:",predicted_class)
# Out:
#      <input type="file" id="files-8faed8a5-2043-4d7f-86be-d5ad0a598311" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8faed8a5-2043-4d7f-86be-d5ad0a598311">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Jenis-Kertas-Buffalo-Kertas-Apakah-Ituu.jpg to Jenis-Kertas-Buffalo-Kertas-Apakah-Ituu (1).jpg
# Maximum Probability:  0.4757823
# Classified: paper
